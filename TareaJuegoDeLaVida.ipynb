# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscar-Hernandez-creator/ODBH_EDD_1358_220/blob/master/TareaJuegoDeLaVida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tarea Juego de la vida parte 1

class Array2D: #Clase Array2D
	def __init__(self,fil,col):
		self.fila = fil
		self.columna = col
		self.arreglo =[ [0 for i in range(col)] for i in range(fil)]

	def get_row_size(self):
		return self.fila
	def get_col_size(self):
		return self.columna
	def set_item(self,fil,col,dato):
		self.arreglo[fil][col] = dato
	def get_item(self,fil,col):
		return self.arreglo[fil][col]
	def to_string(self):
		return self.arreglo


class JuegoDeLaVida:

	def __init__(self,fils,cols,generaciones,poblacion):
		self.largo = cols
		self.alto = fils
		self.grid = Array2D(self.alto,self.largo)
		self.generaciones = generaciones

		for i in poblacion:
			self.grid.set_item(i[0],i[1],1)
		

	def imprime_grid(self):
		for r in range(self.grid.get_col_size()):
			for c in range(self.grid.get_row_size()):
				if self.grid.get_item(r,c) == 0:

					print('░░',end='')
				else:
					print('██',end = '')

			print('')
		print('')

	def get_num_rows(self):
		return self.alto
	def get_num_cols(self):
		return self.largo
	def set_celula_muerta(self,row,col):
		self.grid.set_item(row,col,0)	
	def set_celula_viva(self,row,col):
		self.grid.set_item(row,col,1)	

	def get_is_viva(self,row,col):
		return self.grid.get_item(row,col) == 1

	def get_is_muerta(self,row,col):
		return self.grid.get_item(row,col) == 0

	def get_numero_vecinos_vivos(self,row,col): 
		contador_vecinas = 0

		for i in [row-1, row , row+1]:
			for j in [col-1, col , col+1]:
				try:
					if self.grid.get_item(i,j) == 1  and (i,j) != (row,col):
						contador_vecinas += 1
				except Exception as e:
					pass
					
		return contador_vecinas


	def evolucionar(self): 

		for i in range(self.generaciones):

			array = self.grid.to_string()

			self.imprime_grid()

			lista_siguiente_vivos = []
			lista_siguiente_muertos = []

			for row in range(self.alto):

				for col in range(self.largo):
					if self.get_numero_vecinos_vivos(row,col) == 3:
						lista_siguiente_vivos.append((row,col))

					if self.get_numero_vecinos_vivos(row,col) == 2 :
						pass

					if self.get_numero_vecinos_vivos(row,col) < 2 or self.get_numero_vecinos_vivos(row,col) > 3:
						lista_siguiente_muertos.append((row,col))
			
			for i in lista_siguiente_vivos:
				self.set_celula_viva(i[0],i[1])

			for i in lista_siguiente_muertos:
				self.set_celula_muerta(i[0],i[1])


b = JuegoDeLaVida(7,7,7,[(1,2),(2,2),(2,1),(2,3)]) 

b.evolucionar()
# Out:
# ░░░░░░░░░░░░░░
# ░░░░██░░░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░██████░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░██░░░░░░░░
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ░░░░██░░░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░░░░░░░░░░░
# ░░██████░░░░░░
# ░░██░░██░░░░░░
# ░░██████░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░██░░░░░░░░
# ░░██░░██░░░░░░
# ██░░░░░░██░░░░
# ░░██░░██░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
#
# ░░░░██░░░░░░░░
# ░░██████░░░░░░
# ████░░████░░░░
# ░░██████░░░░░░
# ░░░░██░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
