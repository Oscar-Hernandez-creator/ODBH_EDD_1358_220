# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscar-Hernandez-creator/ODBH_EDD_1358_220/blob/master/23_Oct_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
    def __init__( self , dato ):
        self.__dato = dato
        self.__siguiente = None

    def get_dato( self ):
        return self.__dato

    def set_dato( self , d ):
        self.__dato = d

    def get_siguiente( self ):
        return self.__siguiente

    def set_siguiente( self , d ):
        self.__siguiente = d

    def show( self ):
        curr_node = self # Head
        print(" Inicio de la estructura ligada:")
        print("|" + str(curr_node.get_dato()) + "| -->" , end ="" )
        while( curr_node.get_siguiente() != None ):
            curr_node = curr_node.get_siguiente()
            print("|" + str(curr_node.get_dato() ) + "| -->" , end ="" )
        print("\nFin")

# Ejemplo 1
a = Nodo( 10 )
a.show()

#Ejemplo 2
a.set_siguiente(Nodo(20))
a.show()

#Ejemplo 3
a.get_siguiente().set_siguiente(Nodo(30))
a.show()

#Ejemplo 4
a.get_siguiente().get_siguiente().set_siguiente(Nodo(40))
a.show()

#Ejemplo 5
a.get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(50))
a.show()

#Ejemplo 6 cambio de valor 
a.set_dato(12)
a.show()

#Ejemplo 7 cambio de valor 

a.get_siguiente().get_siguiente().get_siguiente().set_dato(45)
a.show()

#Ejemplo 8
a.get_siguiente().get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(60))
a.show()

#Ejemplo 9
a.get_siguiente().set_dato(25)
a.show()
# Out:
#  Inicio de la estructura ligada:
# |10| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->|40| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->|40| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|40| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|45| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|45| -->|50| -->|60| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|25| -->|30| -->|45| -->|50| -->|60| -->
# Fin

# %%
class Nodo:
    def __init__( self , dato ):
        self.dato = dato
        self.siguiente = None

 #Ejemplo 1
a = Nodo(10)
print(a.dato)
print(a.siguiente)    

#Ejemplo 2
a.siguiente = Nodo (20)

#ejemplo 3
a.siguiente.siguiente=Nodo(30)

#Ejemplo 4
a.siguiente.siguiente.siguiente = Nodo(40)

#Ejemplo 5
a.siguiente.siguiente.siguiente.siguiente = Nodo(50)



#Recorrido transversal
curr_node = a
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

#ejemplo 6
a.siguiente.siguiente.siguiente.dato = 45

#ejemplo 6
a.siguiente.siguiente.dato = 35

#ejemplo 7
a.siguiente.siguiente = a.siguiente.siguiente.siguiente

#ejemplo 8
a.siguiente = a.siguiente.siguiente.siguiente.siguiente

#ej 9


#Recorrido transversal
curr_node = a
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")
# Out:
# 10
# None
# 10 -->20 -->30 -->40 -->50 -->
# 10 -->

# %%
#clase 18 de novoembre 
class Nodo:
    def __init__( self , dato, siguiente = None):
        self.__dato = dato
        self.__siguiente = siguiente

head = Nodo( 10 , Nodo( 20, Nodo( 30, Nodo( 40, Nodo( 50 ) ) ) ) )

#Recorrido transversal
curr_node = head
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

#insertar el nodo 35
anterior = head.siguiente.siguiente
print(anterior.dato)
nuevo = Nodo(35)
nuevo.siguiente = anterior.siguiente
print(nuevo.siguiente.dato)
anterior.siguiente = nuevo

#Recorrido transversal
curr_node = head
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

#eliminar un nodo
head.siguiente = head.siguiente.siguiente
#Recorrido transversal
curr_node = head
print(curr_node.dato , "-->" , end="")
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3ae8179f2308> in <module>()
#       8
#       9 curr_node = head
# ---> 10 print(curr_node.dato , "-->" , end="")
#      11 while( curr_node.siguiente != None ):
#      12     curr_node = curr_node.siguiente
#
# AttributeError: 'Nodo' object has no attribute 'dato'

# %%
class Nodo:
    def __init__( self , dato, siguiente = None):
        self.dato = dato
        self.siguiente = siguiente

class LinkedList:
    def __init__(self):
        self.head =None

    def is_empty(self):
        return self.head == None
    
    def tail(self):
        curr_node = self.__head
        while curr_node != None and curr_node.siguiente !=None:
            curr_node = curr_node.siguiente
        return curr_node
    
    def apend(self,value):
        nuevo = Nodo(value)
        if self.__head = None :
            self.__head = nuevo 
        else:
            self.__tail().siguiente = nuevo
            
    def transversal(self):
        curr_node = self.__head
        if curr_node == None:
            print("Lista vacia")
        else:
            while curr_node != None:
                print(f"{ curr_node.dato } -->", end=" ")
                curr_node = curr_node.siguiente

                print("")

    def prepend(delf,value):
        nuevo = Nodo(Value)
        if self.__head ==None:
            self.__head=nuevo
            else:
                x = self.__head
                self.__head = nuevo
                nuevo.siguiente = x

# %%
l = LinkedList()
print(f"l esta vacia? {l.is_empty()} "  )
x = l.tail()
print(x)
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.transversal()
l.append(5)
l.transversal()
